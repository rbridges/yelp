# %%
import pandas as pd



# read the entire file into a python array
with open('yelp_academic_dataset_business.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = b'[' + b','.join(data) + b']'

# now, load it into pandas
data_df = pd.read_json(data_json_str)
data_df.head(10)
# Out:
#                                           attributes             business_id  \
# 0  {u'Take-out': True, u'Drive-Thru': False, u'Ou...  5UmKMjUEUNdYWqANhGckJw
# 1  {u'Happy Hour': True, u'Accepts Credit Cards':...  UsFtqoBl7naz8AVUBZMjQQ
# 2                                                 {}  3eu6MEFlq2Dg7bQh8QbdOg
# 3                           {u'Good for Kids': True}  cE27W9VPgO88Qxe4ol6y_g
# 4  {u'Accepts Credit Cards': False, u'Price Range...  HZdLhv6COCleJMo7nPl-RA
# 5  {u'Alcohol': u'full_bar', u'Noise Level': u'av...  mVHrayjG3uZ_RLHkLj-AMg
# 6                          {u'Good for Kids': False}  VHYT1qgQw5JvXAlUDhTArA
# 7  {u'Alcohol': u'full_bar', u'Noise Level': u'lo...  KayYbHCt-RkbGcPdGOThNg
# 8                                                 {}  b12U9TFESStdy7CsTtcOeg
# 9                           {u'Good for Kids': True}  Sktj1eHQFuVa-M4bgnEh8g
#
#                                           categories         city  \
# 0                           [Fast Food, Restaurants]   Dravosburg
# 1                                        [Nightlife]   Dravosburg
# 2                          [Auto Repair, Automotive]   Dravosburg
# 3                     [Active Life, Mini Golf, Golf]  Bethel Park
# 4  [Shopping, Home Services, Internet Service Pro...   Pittsburgh
# 5  [Bars, American (New), Nightlife, Lounges, Res...       rankin
# 6     [Active Life, Trainers, Fitness & Instruction]   Pittsburgh
# 7  [Bars, American (Traditional), Nightlife, Rest...     Carnegie
# 8                   [Auto Repair, Automotive, Tires]     Carnegie
# 9                           [Active Life, Mini Golf]     Carnegie
#
#                                        full_address  \
# 0      4734 Lebanon Church Rd\nDravosburg, PA 15034
# 1              202 McClure St\nDravosburg, PA 15034
# 2                 1 Ravine St\nDravosburg, PA 15034
# 3           1530 Hamilton Rd\nBethel Park, PA 15234
# 4     301 South Hills Village\nPittsburgh, PA 15241
# 5                 414 Hawkins Ave\nrankin, PA 15104
# 6  2101 Greentree Rd Ste B201\nPittsburgh, PA 15220
# 7   141 Hawthorne St\nGreentree\nCarnegie, PA 15106
# 8           718A Hope Hollow Rd\nCarnegie, PA 15106
# 9     920 Forsythe Rd\nCarnegie\nCarnegie, PA 15106
#
#                                                hours   latitude  longitude  \
# 0  {u'Tuesday': {u'close': u'21:00', u'open': u'1...  40.354327 -79.900706
# 1                                                 {}  40.350553 -79.886814
# 2                                                 {}  40.350956 -79.889059
# 3                                                 {}  40.354115 -80.014660
# 4  {u'Monday': {u'close': u'21:00', u'open': u'10...  40.357620 -80.059980
# 5  {u'Tuesday': {u'close': u'19:00', u'open': u'1...  40.413464 -79.880247
# 6                                                 {}  40.390386 -80.070897
# 7  {u'Monday': {u'close': u'02:00', u'open': u'11...  40.415517 -80.067534
# 8  {u'Monday': {u'close': u'19:00', u'open': u'07...  40.394588 -80.084454
# 9                                                 {}  40.405404 -80.076267
#
#                                name neighborhoods   open  review_count  stars  \
# 0                         Mr Hoagie            []   True             4    4.5
# 1                      Clancy's Pub            []   True             4    3.5
# 2                  Joe Cislo's Auto            []   True             3    5.0
# 3          Cool Springs Golf Center            []  False             5    2.5
# 4                           Verizon            []   True             5    2.5
# 5                     Emil's Lounge            []   True            20    5.0
# 6                 Extreme Fitness 2            []   True             3    2.5
# 7             Alexion's Bar & Grill   [Greentree]   True            21    4.0
# 8     Flynn's Tire And Auto Service            []   True             7    2.5
# 9  Forsythe Miniature Golf & Snacks    [Carnegie]  False             4    4.0
#
#   state      type
# 0    PA  business
# 1    PA  business
# 2    PA  business
# 3    PA  business
# 4    PA  business
# 5    PA  business
# 6    PA  business
# 7    PA  business
# 8    PA  business
# 9    PA  business

# %%
types = set()
for i in data_df['type']:
    types.add(i)

print(types)

# %%
print(type(data_df['attributes'][0]))

# %%
attributes = {}

for attr in data_df['attributes']:
    for att in attr:
        if att not in attributes:
            attributes[att] = set()
        
        attributes[att].add(type(attr[att]))
        
        
for a in attributes:
    print a, attributes[a]
    print

# %%
    
def printStuff(attributeName):
    yesses = 0.0
    nos = 0.0
    for attr in data_df['attributes']:
        for att in attr:
            if att == attributeName:
                if attr[att] == True:
                    yesses += 1.0
                else:
                    nos += 1.0

    print nos
    print yesses
    print "percent discussing", attributeName, (yesses+nos) / len(data_df)
    print "of those discussing, yesses", yesses/(yesses+nos)
    print "of those discussing, noes", nos/(yesses+nos)  
    print "\n\n"

for attributeName in attributes:
    for t in attributes[attributeName]:
        if t == type(True):
            printStuff(attributeName)

# %%
class CountSet:
    def __init__(self):
        self.entries = {}
        self.total_entry_count = 0
        
    def insert(self, entry):
        if entry not in self.entries:
            self.entries[entry] = 0
        self.entries[entry] += 1
        self.total_entry_count += 1
    
    def printTopN(self, n):
        sortedItems = sorted(self.entries.iteritems(), reverse=True, key=lambda entry: entry[1])    
        printList = ["".join([str(k), " : ", str(v)]) for k,v in sortedItems]
        print "\n".join(printList[:n])
    
    def __getitem__(self, key):
        return self.entries[key]
    
    def __repr__(self):
        sortedItems = sorted(self.entries.iteritems(), reverse=True, key=lambda entry: entry[1])    
        printList = ["".join([str(k), " : ", str(v)]) for k,v in sortedItems]
        return "\n".join(printList)
    
    def __len__(self):
        return self.total_entry_count

categories = set()
for cats in data_df['categories']:
    for cat in cats:
        categories.add(cat)


crossLinks = {}
for cat in categories:
    # each category keeps track of how many times it is listed with other categories
    crossLinks[cat] = CountSet() 
    
for cats in data_df['categories']:
    for cat in cats:
        for otherCat in cats:
            if cat != otherCat:
                crossLinks[cat].insert(otherCat)

stahp = 0
sortedCategories = sorted(crossLinks.iteritems(), reverse=True, key=lambda entry: len(entry[1])) 
# print the cateogories that occur together (which ones are distinguishing?)
for category, similar_set in sortedCategories:
    print category, "has {} occurrences ~~~\n".format(len(similar_set)), similar_set, "\n\n"
    stahp += 1
    if stahp > 0:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-4f247e717a74> in <module>()
#      27
#      28 categories = set()
# ---> 29 for cats in data_df['categories']:
#      30     for cat in cats:
#      31         categories.add(cat)
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'categories'

# %%
from itertools import islice
import re

class CountSet:
    def __init__(self):
        self.entries = {}
        self.total_entry_count = 0
        
    def insert(self, entry):
        if entry not in self.entries:
            self.entries[entry] = 0
        self.entries[entry] += 1
        self.total_entry_count += 1
    
    def printTopN(self, n):
        sortedItems = sorted(self.entries.iteritems(), reverse=True, key=lambda entry: entry[1])    
        printList = ["".join([str(k), " : ", str(v)]) for k,v in sortedItems]
        print "\n".join(printList[:n])
    
    def __getitem__(self, key):
        return self.entries[key]
    
    def __repr__(self):
        sortedItems = sorted(self.entries.iteritems(), reverse=True, key=lambda entry: entry[1])    
        printList = ["".join([str(k), " : ", str(v)]) for k,v in sortedItems]
        return "\n".join(printList)
    
    def __len__(self):
        return self.total_entry_count

def normalize(text):
    text = text.lower()
    text = re.sub("[^\w -]", "", text) # remove all but alphanumerics, dashes and spaces
    text = re.sub(" +", " ", text) # get rid of spaces that might arise from multiple special characters padded by a space getting deleted
    return text.strip()

stopWords = set(normalize(word) for word in open('stopWords2.txt','r').readlines())
print stopWords

f = open('yelp_academic_dataset_review.json', 'rb')
data = islice(f, 50000)

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = b'[' + b','.join(data) + b']'

# now, load it into pandas
data_df = pd.read_json(data_json_str)
#data_df.head(10)

goodWords = CountSet()
badWords = CountSet()
for review in data_df.itertuples():
    stars = review[4]
    reviewText = review[5]
    if stars > 3:
        for token in reviewText.split():
            if token not in stopWords:
                goodWords.insert(normalize(token))
    elif stars < 3:
        for token in reviewText.split():
            if token not in stopWords:
                badWords.insert(normalize(token))  

goodWords.printTopN(20)
print "\n----------\n"
badWords.printTopN(20)
# Out:
# set(['and', 'is', 'it', 'an', 'as', 'at', 'in', 'its', 'from', 'for', 'to', 'has', 'was', 'be', 'that', 'with', 'by', 'he', 'a', 'on', 'i', 'of', 'will', 'were', 'the', 'are'])
# i : 85118
# the : 31552
# my : 29725
# you : 28861
# this : 25793
# but : 25222
# they : 24051
# have : 23613
# we : 19604
# had : 18107
# good : 17130
# great : 17089
# place : 16964
# so : 16344
# not : 15751
# food : 15334
# very : 13251
# it : 13231
# there : 13132
# here : 12918
#
# ----------
#
# i : 43610
# my : 15130
# not : 12625
# we : 12602
# they : 12475
# this : 12444
# the : 12381
# but : 11657
# have : 9920
# you : 9480
# had : 9384
# me : 7489
# so : 7404
# food : 7060
# there : 7057
# if : 5910
# it : 5825
# place : 5669
# out : 5603
# just : 5548
